# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       2
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21611.0  4.580327e+09  2.876592e+09  1.000102e+06
# price          21611.0  5.400850e+05  3.671430e+05  7.500000e+04
# bedrooms       21611.0  3.370830e+00  9.300916e-01  0.000000e+00
# bathrooms      21611.0  2.114791e+00  7.701570e-01  0.000000e+00
# sqft_living    21611.0  2.079853e+03  9.184224e+02  2.900000e+02
# sqft_lot       21611.0  1.510771e+04  4.142235e+04  5.200000e+02
# floors         21611.0  1.494332e+00  5.400034e-01  1.000000e+00
# waterfront     21611.0  7.542455e-03  8.652117e-02  0.000000e+00
# view           21611.0  2.343251e-01  7.663497e-01  0.000000e+00
# condition      21611.0  3.409421e+00  6.507548e-01  1.000000e+00
# grade          21611.0  7.656888e+00  1.175502e+00  1.000000e+00
# sqft_above     21611.0  1.788396e+03  8.281282e+02  2.900000e+02
# sqft_basement  21611.0  2.914574e+02  4.424874e+02  0.000000e+00
# ...

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['price'])
# Out:
# C:\Users\badal\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.countplot(x='bedrooms',data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053182
# id              -0.016742
# long             0.021613
# condition        0.036379
# yr_built         0.054006
# sqft_lot15       0.082448
# sqft_lot         0.089661
# yr_renovated     0.126436
# floors           0.256814
# waterfront       0.266371
# lat              0.307010
# bedrooms         0.308366
# sqft_basement    0.323842
# view             0.397299
# bathrooms        0.525150
# sqft_living15    0.585377
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702055
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='price',y='sqft_living',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_living'>

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='bedrooms',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
sns.scatterplot(x='lat',y='long',data=df)
# Out:
# <AxesSubplot:xlabel='lat', ylabel='long'>

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='price',y='long',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='long'>

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='price',y='lat',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='long',y='lat',data=df,hue='price')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
df.sort_values('price',ascending=False).head(20)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 8092   1924059029  20140617T000000  4668000.0         5       6.75
# 2626   7738500731  20140815T000000  4500000.0         5       5.50
# 8638   3835500195  20140618T000000  4489000.0         4       3.00
# 12370  6065300370  20150506T000000  4208000.0         5       6.00
# 4149   6447300265  20141014T000000  4000000.0         4       5.50
# 2085   8106100105  20141114T000000  3850000.0         4       4.25
# ...

# %%
len(df)*0.01
# Out:
# 216.11

# %%
non_top_1_perc=df.sort_values('price',ascending=False).iloc[216:]

# %%
non_top_1_perc
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 3281   8964800025  20150226T000000  1965000.0         5       3.75
# 12577  2806300065  20150422T000000  1960000.0         4       4.00
# 12283  1923000260  20141015T000000  1959000.0         5       4.50
# 9175   3124059023  20150213T000000  1955000.0         3       1.75
# 1152   4055701200  20150421T000000  1955000.0         4       2.75
# ...           ...              ...        ...       ...        ...
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 1149   3421079032  20150217T000000    75000.0         1       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 3281          3940     13738     1.5           0     3  ...      9
# ...

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='long',y='lat',data=non_top_1_perc,edgecolor=None,alpha=0.2,palette='RdYlGn',hue='price')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df=df.drop('id',axis=1)

# %%
df['date']
# Out:
# 0        20141013T000000
# 1        20141209T000000
# 2        20150225T000000
# 3        20141209T000000
# 4        20150218T000000
#               ...
# 21608    20140521T000000
# 21609    20150223T000000
# 21610    20140623T000000
# 21611    20150116T000000
# 21612    20141015T000000
# Name: date, Length: 21611, dtype: object

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21608   2014-05-21
# 21609   2015-02-23
# 21610   2014-06-23
# 21611   2015-01-16
# 21612   2014-10-15
# Name: date, Length: 21611, dtype: datetime64[ns]

# %%
df['year']=df['date'].apply(lambda date:date.year)

# %%
df['month']=df['date'].apply(lambda date:date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='month',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='price'>

# %%
df.groupby('month').mean()['price']
# Out:
# month
# 1     525870.889571
# 2     507851.371200
# 3     543977.187200
# 4     561792.634978
# 5     550796.041857
# 6     558002.199541
# 7     544788.764360
# 8     536445.276804
# 9     529253.821871
# 10    539026.971778
# 11    521961.009213
# 12    524461.866757
# Name: price, dtype: float64

# %%
df.groupby('month').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.groupby('year').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df=df.drop('date',axis=1)

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  ...  sqft_basement  yr_built  \
# 0               0     0          3      7  ...              0      1955
# ...

# %%
df['zipcode'].value_counts()
# Out:
# 98103    601
# 98038    590
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    105
# 98010    100
# 98024     81
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df['zipcode'].nunique()
# Out:
# 70

# %%
df=df.drop('zipcode',axis=1)

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20697
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['sqft_basement']
# Out:
# 0          0
# 1        400
# 2          0
# 3        910
# 4          0
#         ...
# 21608      0
# 21609      0
# 21610      0
# 21611      0
# 21612      0
# Name: sqft_basement, Length: 21611, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# 0       13125
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 588         1
# 3260        1
# 243         1
# 2570        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7      1180.0              0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21611 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21611 non-null  float64
#  1   bedrooms       21611 non-null  int64
#  2   bathrooms      21611 non-null  float64
#  3   sqft_living    21611 non-null  int64
#  4   sqft_lot       21611 non-null  int64
#  5   floors         21611 non-null  float64
#  6   waterfront     21611 non-null  int64
#  7   view           21611 non-null  int64
#  8   condition      21611 non-null  int64
#  9   grade          21611 non-null  int64
#  10  sqft_above     21611 non-null  float64
#  11  sqft_basement  21611 non-null  int64
#  12  yr_built       21611 non-null  int64
#  13  yr_renovated   21611 non-null  int64
#  14  lat            21611 non-null  float64
#  15  long           21611 non-null  float64
#  16  sqft_living15  21611 non-null  int64
# ...

# %%
X=df.drop('price',axis=1)
y=df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
#X_train = scaler.transform(X_train)
#X_test = scaler.transform(X_test)
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (15127, 19)

# %%
model=Sequential()

# %%
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(1))

model.compile(optimizer='Adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train,validation_data=(X_test,y_test),batch_size=128,epochs=400)
#smaller the batch size longer the training will take
#The batch_size argument in the model.fit() function in Keras specifies the number of samples that are processed before the model is updated. A larger batch size can improve the performance of the model, but it can also make the training process slower. A smaller batch size can make the training process faster, but it may not be as accurate.

#In the code you provided, the batch_size is set to 128. This means that the model will be updated after every 128 samples are processed. This is a good compromise between performance and speed.
# Out:
# Epoch 1/400
# 119/119 [==============================] - 2s 6ms/step - loss: 426874208256.0000 - val_loss: 425348235264.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 4ms/step - loss: 424611381248.0000 - val_loss: 417468710912.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 4ms/step - loss: 394436378624.0000 - val_loss: 350164123648.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 4ms/step - loss: 268216123392.0000 - val_loss: 180970536960.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 4ms/step - loss: 136746287104.0000 - val_loss: 112656326656.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 4ms/step - loss: 101486886912.0000 - val_loss: 92455313408.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 3ms/step - loss: 82645213184.0000 - val_loss: 76289482752.0000
# Epoch 8/400
# ...

# %%
model.history.history
# Out:
# {'loss': [426874208256.0,
#   424611381248.0,
#   394436378624.0,
#   268216123392.0,
#   136746287104.0,
#   101486886912.0,
#   82645213184.0,
#   68236705792.0,
#   58547351552.0,
#   53017595904.0,
#   49832357888.0,
#   47685242880.0,
#   46117199872.0,
#   44717879296.0,
#   43548491776.0,
#   42532409344.0,
#   41664180224.0,
#   40905969664.0,
#   40193314816.0,
#   39607500800.0,
#   39080505344.0,
#   38575280128.0,
#   38200377344.0,
#   37805985792.0,
#   37398093824.0,
#   37112279040.0,
#   36810248192.0,
#   36543934464.0,
#   36260978688.0,
#   36052422656.0,
#   35847741440.0,
#   35594072064.0,
#   35425878016.0,
#   35200270336.0,
#   35040243712.0,
#   34904313856.0,
#   34707365888.0,
#   34586714112.0,
#   34397245440.0,
#   34209286144.0,
#   34121637888.0,
#   33914161152.0,
#   33892251648.0,
#   33683224576.0,
#   33537218560.0,
#   33386131456.0,
#   33305964544.0,
#   33168324608.0,
#   33036711936.0,
#   32951119872.0,
#   32859162624.0,
# ...

# %%
df_loss = pd.DataFrame(model.history.history)

# %%
df_loss
#loss is the training set loss and val_loss is the testing set loss
# Out:
#              loss      val_loss
# 0    4.268742e+11  4.253482e+11
# 1    4.246114e+11  4.174687e+11
# 2    3.944364e+11  3.501641e+11
# 3    2.682161e+11  1.809705e+11
# 4    1.367463e+11  1.126563e+11
# ..            ...           ...
# 395  2.538428e+10  2.814746e+10
# 396  2.535945e+10  2.811454e+10
# 397  2.536154e+10  2.823093e+10
# 398  2.532973e+10  2.830458e+10
# 399  2.536107e+10  2.825539e+10
#
# [400 rows x 2 columns]

# %%
df_loss.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# %%
predictions=model.predict(X_test)
# Out:
# 203/203 [==============================] - 1s 2ms/step

# %%
mean_squared_error(y_test,predictions)
# Out:
# 28255387979.58942

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 168093.39064814363

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 101127.27993185147

# %%
df['price'].describe()
# Out:
# count    2.161100e+04
# mean     5.400850e+05
# std      3.671430e+05
# min      7.500000e+04
# 25%      3.217250e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.7874585866092689

# %%
plt.figure(figsize=(12,6))
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,'r')

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7      1180.0              0
# ...

# %%
single_house=df.drop('price',axis=1).iloc[0]

# %%
single_house=scaler.transform(single_house.values.reshape(-1,19))
# Out:
# C:\Users\badal\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
model.predict(single_house)
# Out:
# 1/1 [==============================] - 0s 56ms/step
# array([[254003.7]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7      1180.0              0      1955             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month
# 0  47.5112 -122.257           1340        5650  2014     10
